# %%
# gather and First Glance at the Data
import pandas as pd

# %%
# read the CSV file
data = pd.read_csv('../data/creditcard_normal.csv')
# data = pd.read_csv('../data/creditcard_fraud.csv')
print(data.describe())

# only use the 'Amount' and 'V1', ..., 'V28' features
features = ['Amount'] + ['V%d' % number for number in range(1, 29)]

# now create an X variable (containing the features) and an y variable (containing only the target variable)
X = data[features]
# Out:
#                Time          V1          V2          V3          V4  \
# count    118.000000  118.000000  118.000000  118.000000  118.000000
# mean   23081.847458   -7.239790    5.498393  -10.347760    5.906132
# std    11721.323924    8.943498    4.629896    9.230516    2.776939
# min      406.000000  -30.552380   -5.198360  -31.103685    0.817253
# 25%    11749.500000  -14.400619    2.509330  -18.698342    3.894252
# 50%    25242.500000   -3.509069    4.139352   -6.450742    6.047028
# 75%    33878.250000   -0.886762    8.266765   -3.676837    6.770085
# max    41194.000000    1.234235   16.713389    2.041003   11.927512
#
#                V5          V6          V7          V8          V9  \
# count  118.000000  118.000000  118.000000  118.000000  118.000000
# mean    -5.153817   -2.293197   -7.534351    3.611028   -3.121473
# std      6.715638    1.596610    6.936435    5.901177    2.324358
# min    -22.105532   -4.977692  -21.922811   -3.277535   -7.175097
# 25%     -8.255120   -3.345467  -14.744455    0.125125   -4.842605
# 50%     -2.840711   -2.358918   -5.381276    1.226037   -3.604366
# 75%     -0.179455   -1.231852   -1.695177    3.980490   -1.288463
# max      5.269255    3.628382    5.431271   20.007208    2.820829
#
#           ...              V20         V21         V22         V23  \
# count     ...       118.000000  118.000000  118.000000  118.000000
# mean      ...         0.656317    0.741922   -0.288001   -0.291672
# std       ...         0.888072    1.308790    0.890508    2.001297
# min       ...        -3.042626   -2.475962   -2.288686  -19.254328
# 25%       ...         0.174485    0.218599   -0.793487   -0.604253
# 50%       ...         0.577877    0.739044   -0.212400   -0.116313
# 75%       ...         1.450469    1.776412    0.325402    0.275895
# max       ...         2.102339    2.839596    1.745315    2.661291
#
#               V24         V25         V26         V27         V28       Amount
# count  118.000000  118.000000  118.000000  118.000000  118.000000   118.000000
# mean    -0.184753    0.301101    0.182497    0.861271    0.145603    91.075593
# std      0.526636    1.137986    0.375278    1.081062    0.637630   241.834249
# min     -1.632653   -4.781606   -0.657488   -3.908080   -1.869290     0.000000
# 25%     -0.493702   -0.326643   -0.209244    0.326376    0.056594     1.000000
# 50%     -0.028890    0.235577    0.274517    0.803376    0.310510     3.775000
# 75%      0.164333    1.296407    0.521540    1.594390    0.497165    99.990000
# max      0.645545    2.208209    0.816762    3.052358    1.130625  1809.680000
#
# [8 rows x 30 columns]

# %%
# include all the dependendies
from keras.layers import Dense
from keras.models import Sequential
import matplotlib.pyplot as plt

# %%
# define the model
model = Sequential()
model.add(Dense(units=58,
    input_dim=29,
    activation='relu'))
model.add(Dense(units=40,
    activation='relu'))
model.add(Dense(units=15,
    activation='relu'))

# output layer
model.add(Dense(units=1,
    activation='sigmoid'))

# load pre-trained model weights
model.load_weights('credit_model.h5')

# compile
model.compile(loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# %%
# predict model
ynew = model.predict_classes(X)

# show the inputs and predicted outputs
for i in range(len(X)):
    if ynew[i] == 0:
        class_label = 'Normal'
    else:
        class_label = 'Fradulent'

    print("%d --> class=%s" % (i, class_label))
# Out:
# 0 --> class=Fradulent
# 1 --> class=Normal
# 2 --> class=Fradulent
# 3 --> class=Fradulent
# 4 --> class=Normal
# 5 --> class=Fradulent
# 6 --> class=Fradulent
# 7 --> class=Fradulent
# 8 --> class=Fradulent
# 9 --> class=Fradulent
# 10 --> class=Fradulent
# 11 --> class=Fradulent
# 12 --> class=Fradulent
# 13 --> class=Fradulent
# 14 --> class=Fradulent
# 15 --> class=Fradulent
# 16 --> class=Fradulent
# 17 --> class=Fradulent
# 18 --> class=Fradulent
# 19 --> class=Fradulent
# 20 --> class=Fradulent
# 21 --> class=Fradulent
# 22 --> class=Fradulent
# 23 --> class=Fradulent
# 24 --> class=Normal
# 25 --> class=Fradulent
# 26 --> class=Fradulent
# 27 --> class=Fradulent
# 28 --> class=Fradulent
# 29 --> class=Fradulent
# 30 --> class=Fradulent
# 31 --> class=Fradulent
# 32 --> class=Fradulent
# 33 --> class=Fradulent
# 34 --> class=Fradulent
# 35 --> class=Fradulent
# 36 --> class=Fradulent
# 37 --> class=Fradulent
# 38 --> class=Fradulent
# 39 --> class=Normal
# 40 --> class=Normal
# 41 --> class=Normal
# 42 --> class=Fradulent
# 43 --> class=Fradulent
# 44 --> class=Fradulent
# 45 --> class=Fradulent
# 46 --> class=Fradulent
# 47 --> class=Fradulent
# 48 --> class=Fradulent
# 49 --> class=Fradulent
# 50 --> class=Fradulent
# 51 --> class=Fradulent
# 52 --> class=Fradulent
# 53 --> class=Fradulent
# 54 --> class=Fradulent
# 55 --> class=Fradulent
# 56 --> class=Normal
# 57 --> class=Normal
# 58 --> class=Fradulent
# 59 --> class=Fradulent
# 60 --> class=Normal
# 61 --> class=Fradulent
# 62 --> class=Fradulent
# 63 --> class=Fradulent
# 64 --> class=Fradulent
# 65 --> class=Fradulent
# 66 --> class=Fradulent
# 67 --> class=Fradulent
# 68 --> class=Fradulent
# 69 --> class=Fradulent
# 70 --> class=Fradulent
# 71 --> class=Fradulent
# 72 --> class=Fradulent
# 73 --> class=Fradulent
# 74 --> class=Fradulent
# 75 --> class=Fradulent
# 76 --> class=Fradulent
# 77 --> class=Fradulent
# 78 --> class=Fradulent
# 79 --> class=Fradulent
# 80 --> class=Fradulent
# 81 --> class=Fradulent
# 82 --> class=Fradulent
# 83 --> class=Fradulent
# 84 --> class=Fradulent
# 85 --> class=Normal
# 86 --> class=Fradulent
# 87 --> class=Fradulent
# 88 --> class=Fradulent
# 89 --> class=Normal
# 90 --> class=Fradulent
# 91 --> class=Fradulent
# 92 --> class=Fradulent
# 93 --> class=Fradulent
# 94 --> class=Fradulent
# 95 --> class=Fradulent
# 96 --> class=Fradulent
# 97 --> class=Fradulent
# 98 --> class=Fradulent
# 99 --> class=Fradulent
# 100 --> class=Fradulent
# 101 --> class=Fradulent
# 102 --> class=Fradulent
# 103 --> class=Normal
# 104 --> class=Fradulent
# 105 --> class=Fradulent
# 106 --> class=Fradulent
# 107 --> class=Fradulent
# 108 --> class=Fradulent
# 109 --> class=Fradulent
# 110 --> class=Fradulent
# 111 --> class=Fradulent
# 112 --> class=Fradulent
# 113 --> class=Fradulent
# 114 --> class=Fradulent
# 115 --> class=Fradulent
# 116 --> class=Fradulent
# 117 --> class=Fradulent
